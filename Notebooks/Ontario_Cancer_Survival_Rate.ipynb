# %%
# import dependecies
import pandas as pd
import numpy as np

# %%
# Read the data into a Pandas DataFrame
Cancer_Survival_df = pd.read_excel('OntarioCancerProfilesSurvival.xlsx')
Cancer_Survival_df.head()
# Out:
#                         Ontario Cancer Profiles Data
# 0                                           Contents
# 1                                    Data Dictionary
# 2                      Cancer Survival by sub-region
# 3                              data source and notes
# 4  Cancer Survival by public health unit (PHU) (2...

# %%
# Access the Sub-region worksheet
Cancer_Survival_by_sub_region_df = pd.read_excel('OntarioCancerProfilesSurvival.xlsx', sheet_name= 'Sub-region')
Cancer_Survival_by_sub_region_df.head(10)
# Out:
#   Cancer site         Sex                  Age    Years  RegionID  \
# 0  All cancer  Both sexes  all ages (15 to 99)  2014-18    3501.0
# 1  All cancer  Both sexes  all ages (15 to 99)  2014-18    3502.0
# 2  All cancer  Both sexes  all ages (15 to 99)  2014-18    3503.0
# 3  All cancer  Both sexes  all ages (15 to 99)  2014-18    3504.0
# 4  All cancer  Both sexes  all ages (15 to 99)  2014-18    3505.0
# 5  All cancer  Both sexes  all ages (15 to 99)  2014-18    3506.0
# 6  All cancer  Both sexes  all ages (15 to 99)  2014-18    3507.0
# 7  All cancer  Both sexes  all ages (15 to 99)  2014-18    3508.0
# 8  All cancer  Both sexes  all ages (15 to 99)  2014-18    3509.0
# 9  All cancer  Both sexes  all ages (15 to 99)  2014-18    3510.0
#
#                              Region 5-year RSR (%)   SE Lower 95%CI  \
# 0                     Erie St Clair           62.9  0.6        61.8
# 1                        South West           65.4  0.5        64.5
# 2               Waterloo Wellington           65.7  0.6        64.5
# 3  Hamilton Niagara Haldimand Brant           64.6  0.4        63.9
# 4                      Central West           69.4  0.6        68.2
# 5                Mississauga Halton           70.7  0.5        69.7
# 6                   Toronto Central           68.9  0.5          68
# 7                           Central           72.6  0.4        71.9
# 8                      Central East           66.3  0.4        65.5
# 9                        South East           63.8  0.6        62.6
#
#   Upper 95%CI
# 0        63.9
# 1        66.3
# 2        66.8
# 3        65.4
# 4        70.5
# 5        71.6
# 6        69.8
# 7        73.3
# 8          67
# 9          65

# %%
# Access the Data Dictionary worksheet
Cancer_Survival_Data_Dictionary_df = pd.read_excel('OntarioCancerProfilesSurvival.xlsx', sheet_name= 'Data Dictionary')
Cancer_Survival_Data_Dictionary_df.head(10)
# Out:
#     Variable Name      Data Type  \
# 0     Cancer Site    Categorical
# 1             Sex    Categorical
# 2             Age   Categorical
# 3            Year    Categorical
# 4        RegionID    Categorical
# 5          Region    Categorical
# 6  5-year RSR (%)  Quantitative
# 7              SE  Quantitative
# 8    Lower 95% CI  Quantitative
# 9    Upper 95% CI   Quantitative
#
#                                          Description  \
# 0  Cancer type, including and all cancer types gr...
# 1                      Females, males and both sexes
# 2                                        Age groups
# 3  Period of follow-up years for persons diagnose...
# 4          Unique identifier code for health regions
# 5                     Ontario and the health regions
# 6  Five-year Relative Survival Ratio (RSR). The R...
# 7                         Standard error for the RSR
# 8  Lower limit of 95% confidence interval for the...
# 9  Upper limit of 95% confidence interval for the...
#
#                                              Comment
# 0  The location in the body (site) of the initial...
# 1  This refers to a person's sex as recorded on h...
# 2  Additonal age groups are provided for those ca...
# 3  RSRs were estimated using the period method. P...
# 4            "35" represents the Ontario comparator.
# 5  The Ontario RSRs exclude cases with unknown re...
# 6  RSRs are expressed as percentages. RSRs for al...
# 7             A measure of the precision of the RSR.
# 8  An estimate of a potential lower value of the ...
# 9  An estimate of a potential higher value of the...

# %%
# Access the 36 phus worksheet
Cancer_Survival_36_df = pd.read_excel('OntarioCancerProfilesSurvival.xlsx', sheet_name= '36 PHUs (2005-17 boundaries)')
Cancer_Survival_36_df.head(10)
# Out:
#   Cancer site         Sex                  Age    Years  RegionID  \
# 0  All cancer  Both sexes  all ages (15 to 99)  2014-18    3526.0
# 1  All cancer  Both sexes  all ages (15 to 99)  2014-18    3527.0
# 2  All cancer  Both sexes  all ages (15 to 99)  2014-18    3530.0
# 3  All cancer  Both sexes  all ages (15 to 99)  2014-18    3533.0
# 4  All cancer  Both sexes  all ages (15 to 99)  2014-18    3534.0
# 5  All cancer  Both sexes  all ages (15 to 99)  2014-18    3535.0
# 6  All cancer  Both sexes  all ages (15 to 99)  2014-18    3536.0
# 7  All cancer  Both sexes  all ages (15 to 99)  2014-18    3537.0
# 8  All cancer  Both sexes  all ages (15 to 99)  2014-18    3538.0
# 9  All cancer  Both sexes  all ages (15 to 99)  2014-18    3539.0
#
#                             Region 5-year RSR (%)   SE Lower 95%CI Upper 95%CI
# 0                           Algoma           62.8  1.1        60.5          65
# 1                     Brant County           62.3  1.3        59.7        64.7
# 2                    Durham Region           67.2  0.6          66        68.4
# 3                       Grey-Bruce           67.1    1        65.1          69
# 4                Haldimand-Norfolk           63.3  1.3        60.8        65.7
# 5   Haliburton Kawartha Pine Ridge           63.6  0.9        61.8        65.4
# 6                    Halton Region           71.6  0.7        70.3        72.9
# 7                         Hamilton           63.4  0.6        62.1        64.6
# 8  Hastings Prince Edward Counties           61.8    1        59.7        63.8
# 9                     Huron County           63.9  1.7        60.3        67.2

# %%
# Export Sub-region worksheet as a csv
Cancer_Survival_by_sub_region_df.to_csv("Sub-region.csv", index=False)

# %%
# Export Sub-region worksheet as a csv
Cancer_Survival_Data_Dictionary_df.to_csv("Data_Dictionary.csv", index=False)

# %%
# Export Sub-region worksheet as a csv
Cancer_Survival_36_df.to_csv("36 PHUs (2005-17 boundaries).csv", index=False)
